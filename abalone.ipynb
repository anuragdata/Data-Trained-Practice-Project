# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
abalone=pd.read_csv("abalone.csv")

# %%
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df=pd.DataFrame(data=abalone)
df.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %% [markdown]
# Exploratory Data Analysis

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
abalone["Sex"].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
le=LabelEncoder()
df["Sex"]=le.fit_transform(df["Sex"])

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
fig=plt.figure(figsize=(10,8))
hs=df.corr(method='pearson')
sns.heatmap(hs,annot=True,cmap='Blues')

# %% [markdown]
# Visualization

# %%
sns.pairplot(df)

# %%
df.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# Sex                  AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Length            AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Diameter           AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Height            AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Whole weight      AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Shucked weight          AxesSubplot(0.125,0.125;0.133621x0.343182)
# Viscera weight       AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Shell weight          AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Rings                AxesSubplot(0.606034,0.125;0.133621x0.343182)
# dtype: object

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
columns=df.columns


for i in df[columns]:
    plt.figure()
    sns.distplot(df[i])

# %%
ds=df.drop(['Sex'],axis=1)

# %% [markdown]
# Here we drop Sex column, since it is weekly correlated with Output variable Ring

# %%
y=ds['Rings']
x=ds.iloc[:,0:-1]

# %%
x.shape
# Out:
# (4177, 7)

# %%
y.shape
# Out:
# (4177,)

# %%
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer()
power.fit_transform(x)
# Out:
# array([[-0.68550213, -0.54986033, -1.12451192, ..., -0.54098937,
#         -0.69328289, -0.587809  ],
#        [-1.39634403, -1.38733299, -1.26439579, ..., -1.31166208,
#         -1.33295268, -1.33241968],
#        [-0.07077438,  0.00853714, -0.06482301, ..., -0.36611642,
#         -0.25513514, -0.09826193],
#        ...,
#        [ 0.59336612,  0.64519089,  1.56508168, ...,  0.83813658,
#          1.01560749,  0.59839786],
#        [ 0.85337516,  0.76992788,  0.30708344, ...,  0.85873857,
#          0.81518436,  0.51914542],
#        [ 1.83447784,  1.72628889,  1.34794324, ...,  2.10364827,
#          1.61134422,  1.65848824]])

# %% [markdown]
# Maschine Learning Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso,Ridge

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(x_train,y_train)
# Out:
# 0.5092734453394365

# %%
pred=lr.predict(x_test)

# %%
print(r2_score(y_test,pred))
# Out:
# 0.5653703519690483

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 1.5694955533008743
# Mean squared error: 4.66454910898406
# Root squared error: 2.1597567244909923

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
predr=dtr.predict(x_test)

# %%
predr
# Out:
# array([ 9., 12.,  8., ..., 15.,  8.,  6.])

# %%
test=np.array([0.440,0.365,0.125,0.5160,0.2155,0.1140,0.155])

# %%
test=test.reshape(1,-1)

# %%
print(dtr.predict(test))
# Out:
# [10.]

# %%
t=np.array([0.455,0.365,0.095,0.5140,0.2245,0.1010,0.150])

# %%
t=t.reshape(1,-1)

# %%
print(dtr.predict(t))
# Out:
# [15.]

# %% [markdown]
# Decision Tree Regressor model have better score than Linear Regression. Hence we choose Decision Tree model.

# %%
import joblib

# %%
joblib.dump(dtr,'abalone.obj') #dumping the value
# Out:
# ['abalone.obj']

# %%
abal=joblib.load('abalone.obj') #loading the value
abal.predict(x_test)
# Out:
# array([ 9., 12.,  8., ..., 15.,  8.,  6.])
